# %%
import torch
import monai
from monai.utils import first, set_determinism
from monai.transforms import (
    AsDiscrete,
    AsDiscreted,
    EnsureChannelFirstd,
    Compose,
    CropForegroundd,
    LoadImaged,
    Orientationd,
    RandCropByPosNegLabeld,
    SaveImaged,
    ScaleIntensityRanged,
    Spacingd, 
    EnsureTyped,
    EnsureType,
    Invertd,
    KeepLargestConnectedComponent,
    AddChanneld,
    RandFlipd,
    RandRotate90d,
    RandShiftIntensityd,
    Zoomd,
    RandRotated,
    ToTensord
    
)

# from monai.handlers.utils import from_engine
from monai.networks.nets import UNet
from monai.networks.layers import Norm
from monai.metrics import DiceMetric
from monai.losses import DiceLoss
from monai.inferers import sliding_window_inference
from monai.data import CacheDataset, DataLoader, Dataset, decollate_batch
from monai.config import print_config
from monai.apps import download_and_extract
import matplotlib.pyplot as plt
import tempfile
import shutil
import os
import glob
import nibabel as nib
import numpy as np
from tqdm.notebook import tqdm

# %% [markdown]
# ### Dataset

# %%
root_dir = "/scratch/scratch6/akansh12/Parse_data/train/train/"
train_images = sorted(glob.glob(os.path.join(root_dir, "*", 'image', "*.nii.gz")))
train_labels = sorted(glob.glob(os.path.join("./labels/", "*.nii.gz")))

data_dicts = [{"images": images_name, "labels": label_name} for images_name, label_name in zip(train_images, train_labels)]
train_files, val_files = data_dicts[:-9], data_dicts[-9:]
set_determinism(seed = 0)

# %% [markdown]
# ### Transforms

# %%
train_transforms = Compose(
    [
        LoadImaged(keys=["images", "labels"]),
        AddChanneld(keys=["images", "labels"]),
        Orientationd(keys=["images", "labels"], axcodes="LPS"),
        # Spacingd(keys=['images', 'labels'], pixdim = (1.5,1.5,2), mode = ("bilinear", 'nearest')),
        ScaleIntensityRanged(
            keys=["images"],
            a_min=-1000,
            a_max=1000,
            b_min=0.0,
            b_max=1.0,
            clip=True,
        ),
        CropForegroundd(keys=["images", "labels"], source_key="images"),
        RandCropByPosNegLabeld(
            keys=["images", "labels"],
            label_key="labels",
            spatial_size=(160, 160, 160),
            pos=1,
            neg=1,
            num_samples=4,
            image_key="images",
            image_threshold=0,
        ),
        RandFlipd(
            keys=["images", "labels"],
            spatial_axis=[0],
            prob=0.30,
        ),
        RandFlipd(
            keys=["images", "labels"],
            spatial_axis=[1],
            prob=0.30,
        ),
        RandFlipd(
            keys=["images", "labels"],
            spatial_axis=[2],
            prob=0.30,
        ),
        RandRotate90d(
            keys=["images", "labels"],
            prob=0.20,
            max_k=3,
        ),
        RandShiftIntensityd(
            keys=["images"],
            offsets=0.10,
            prob=0.40,
        ),
        Zoomd(keys = ['images', 'labels'], zoom = 1.3, mode = ['area', 'nearest'], prob = 0.3),
        RandRotated(keys = ['images', 'labels'], prob=0.3, range_x =[0.4,0.4],mode = ("bilinear", 'nearest')),
        ToTensord(keys=["images", "labels"]),
    ]
)

val_transforms = Compose(
    [
        LoadImaged(keys=["images", "labels"]),
        EnsureChannelFirstd(keys=["images", "labels"]),
        Orientationd(keys=["images", "labels"], axcodes="LPS"),
        ScaleIntensityRanged(
            keys=["images"], a_min=-1000, a_max=1000,
            b_min=0.0, b_max=1.0, clip=True,
        ),
        CropForegroundd(keys=["images", "labels"], source_key="images"),
        EnsureTyped(keys=["images", "labels"]),
    ]
)

# %%
train_ds = CacheDataset(
    data = train_files, transform = train_transforms,
    cache_rate = 1.0, num_workers = 4
)

train_loader = DataLoader(train_ds, batch_size = 2, shuffle = True, num_workers=4)
val_ds = CacheDataset(
    data = val_files, transform = val_transforms,
    cache_rate = 1.0, num_workers = 4
)
val_loader = DataLoader(val_ds, batch_size = 1, shuffle = False, num_workers=4)
# Out:
# Loading dataset:   0%|                                                                                                                                                       | 0/91 [00:02<?, ?it/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tools/anaconda3/envs/torch37/lib/python3.7/multiprocessing/pool.py in next(self, timeout)
#     732             try:
# --> 733                 item = self._items.popleft()
#     734             except IndexError:
#
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_29825/3455442144.py in <module>
#       1 train_ds = CacheDataset(
#       2     data = train_files, transform = train_transforms,
# ----> 3     cache_rate = 1.0, num_workers = 4
#       4 )
#       5
#
# /scratch/scratch6/akansh12/env/lib/python3.7/site-packages/monai/data/dataset.py in __init__(self, data, transform, cache_num, cache_rate, num_workers, progress, copy_cache, as_contiguous, hash_as_key, hash_func)
#     721         self.cache_num = 0
#     722         self._cache: Union[List, Dict] = []
# --> 723         self.set_data(data)
#     724
#     725     def set_data(self, data: Sequence):
#
# /scratch/scratch6/akansh12/env/lib/python3.7/site-packages/monai/data/dataset.py in set_data(self, data)
#     746         else:
#     747             self.data = data
# --> 748             self._cache = _compute_cache()
#     749
#     750     def _fill_cache(self) -> List:
#
# /scratch/scratch6/akansh12/env/lib/python3.7/site-packages/monai/data/dataset.py in _compute_cache()
#     735         def _compute_cache():
#     736             self.cache_num = min(int(self.set_num), int(len(self.data) * self.set_rate), len(self.data))
# --> 737             return self._fill_cache()
#     738
#     739         if self.hash_as_key:
#
# /scratch/scratch6/akansh12/env/lib/python3.7/site-packages/monai/data/dataset.py in _fill_cache(self)
#     759                         p.imap(self._load_cache_item, range(self.cache_num)),
#     760                         total=self.cache_num,
# --> 761                         desc="Loading dataset",
#     762                     )
#     763                 )
#
# /scratch/scratch6/akansh12/env/lib/python3.7/site-packages/tqdm/std.py in __iter__(self)
#    1193
#    1194         try:
# -> 1195             for obj in iterable:
#    1196                 yield obj
#    1197                 # Update and possibly print the progressbar.
#
# /tools/anaconda3/envs/torch37/lib/python3.7/multiprocessing/pool.py in next(self, timeout)
#     735                 if self._index == self._length:
#     736                     raise StopIteration from None
# --> 737                 self._cond.wait(timeout)
#     738                 try:
#     739                     item = self._items.popleft()
#
# /tools/anaconda3/envs/torch37/lib/python3.7/threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:

# %%
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu") 

UNet_meatdata = dict(
    spatial_dims=3,
    in_channels=1,
    out_channels=2,
    channels=(16, 32, 64, 128, 256),
    strides=(2, 2, 2, 2),
    num_res_units=2,
    norm=Norm.BATCH
)
model = UNet(**UNet_meatdata).to(device)

# %%
## Weight Initialization

# %%
# !zip -r labels_main_artery.zip ./labels/
# Out:
# updating: labels/ (stored 0%)
#   adding: labels/PA000148.nii.gz (deflated 95%)
#   adding: labels/PA000229.nii.gz (deflated 95%)
#   adding: labels/PA000132.nii.gz (deflated 96%)
#   adding: labels/PA000233.nii.gz (deflated 94%)
#   adding: labels/PA000005.nii.gz (deflated 95%)
#   adding: labels/PA000082.nii.gz (deflated 94%)
#   adding: labels/PA000296.nii.gz (deflated 97%)
#   adding: labels/PA000157.nii.gz (deflated 96%)
#   adding: labels/PA000107.nii.gz (deflated 94%)
#   adding: labels/PA000234.nii.gz (deflated 95%)
#   adding: labels/PA000162.nii.gz (deflated 95%)
#   adding: labels/PA000226.nii.gz (deflated 95%)
#   adding: labels/PA000263.nii.gz (deflated 94%)
#   adding: labels/PA000144.nii.gz (deflated 95%)
#   adding: labels/PA000070.nii.gz (deflated 95%)
#   adding: labels/PA000147.nii.gz (deflated 95%)
#   adding: labels/PA000245.nii.gz (deflated 95%)
#   adding: labels/PA000183.nii.gz (deflated 94%)
#   adding: labels/PA000047.nii.gz (deflated 95%)
#   adding: labels/PA000120.nii.gz (deflated 94%)
#   adding: labels/PA000313.nii.gz (deflated 96%)
#   adding: labels/PA000190.nii.gz (deflated 95%)
#   adding: labels/PA000078.nii.gz (deflated 95%)
#   adding: labels/PA000286.nii.gz (deflated 97%)
#   adding: labels/PA000297.nii.gz (deflated 96%)
#   adding: labels/PA000212.nii.gz (deflated 96%)
#   adding: labels/PA000310.nii.gz (deflated 95%)
#   adding: labels/PA000223.nii.gz (deflated 95%)
#   adding: labels/PA000100.nii.gz (deflated 94%)
#   adding: labels/PA000128.nii.gz (deflated 95%)
#   adding: labels/PA000138.nii.gz (deflated 96%)
#   adding: labels/PA000118.nii.gz (deflated 95%)
#   adding: labels/PA000236.nii.gz (deflated 95%)
#   adding: labels/PA000300.nii.gz (deflated 96%)
#   adding: labels/PA000314.nii.gz (deflated 96%)
#   adding: labels/PA000305.nii.gz (deflated 96%)
#   adding: labels/PA000201.nii.gz (deflated 96%)
#   adding: labels/PA000042.nii.gz (deflated 97%)
#   adding: labels/PA000307.nii.gz (deflated 96%)
#   adding: labels/PA000024.nii.gz (deflated 95%)
#   adding: labels/PA000096.nii.gz (deflated 93%)
#   adding: labels/PA000106.nii.gz (deflated 95%)
#   adding: labels/PA000036.nii.gz (deflated 95%)
#   adding: labels/PA000099.nii.gz (deflated 97%)
#   adding: labels/PA000169.nii.gz (deflated 95%)
#   adding: labels/PA000116.nii.gz (deflated 95%)
#   adding: labels/PA000080.nii.gz (deflated 95%)
#   adding: labels/PA000284.nii.gz (deflated 96%)
#   adding: labels/PA000255.nii.gz (deflated 96%)
#   adding: labels/PA000298.nii.gz (deflated 96%)
#   adding: labels/PA000239.nii.gz (deflated 93%)
#   adding: labels/PA000046.nii.gz (deflated 95%)
#   adding: labels/PA000303.nii.gz (deflated 95%)
#   adding: labels/PA000302.nii.gz (deflated 97%)
#   adding: labels/PA000133.nii.gz (deflated 94%)
#   adding: labels/PA000195.nii.gz (deflated 95%)
#   adding: labels/PA000202.nii.gz (deflated 94%)
#   adding: labels/PA000238.nii.gz (deflated 96%)
#   adding: labels/PA000038.nii.gz (deflated 96%)
#   adding: labels/PA000092.nii.gz (deflated 96%)
#   adding: labels/PA000309.nii.gz (deflated 96%)
#   adding: labels/PA000060.nii.gz (deflated 95%)
#   adding: labels/PA000203.nii.gz (deflated 95%)
#   adding: labels/PA000063.nii.gz (deflated 95%)
#   adding: labels/PA000027.nii.gz (deflated 95%)
#   adding: labels/PA000174.nii.gz (deflated 95%)
#   adding: labels/PA000124.nii.gz (deflated 95%)
#   adding: labels/PA000315.nii.gz (deflated 97%)
#   adding: labels/PA000150.nii.gz (deflated 95%)
#   adding: labels/PA000090.nii.gz (deflated 96%)
#   adding: labels/PA000292.nii.gz (deflated 96%)
#   adding: labels/PA000168.nii.gz (deflated 95%)
#   adding: labels/PA000115.nii.gz (deflated 95%)
#   adding: labels/PA000301.nii.gz (deflated 95%)
#   adding: labels/PA000261.nii.gz (deflated 95%)
#   adding: labels/PA000137.nii.gz (deflated 95%)
#   adding: labels/PA000217.nii.gz (deflated 94%)
#   adding: labels/PA000237.nii.gz (deflated 95%)
#   adding: labels/PA000194.nii.gz (deflated 94%)
#   adding: labels/PA000026.nii.gz (deflated 95%)
#   adding: labels/PA000056.nii.gz (deflated 94%)
#   adding: labels/PA000109.nii.gz (deflated 95%)
#   adding: labels/PA000317.nii.gz (deflated 94%)
#   adding: labels/PA000242.nii.gz (deflated 95%)
#   adding: labels/PA000209.nii.gz (deflated 95%)
#   adding: labels/PA000125.nii.gz (deflated 94%)
#   adding: labels/PA000198.nii.gz (deflated 95%)
#   adding: labels/PA000074.nii.gz (deflated 96%)
#   adding: labels/PA000053.nii.gz (deflated 94%)
#   adding: labels/PA000273.nii.gz (deflated 95%)
#   adding: labels/PA000235.nii.gz (deflated 95%)
#   adding: labels/PA000073.nii.gz (deflated 94%)
#   adding: labels/PA000285.nii.gz (deflated 95%)
#   adding: labels/PA000127.nii.gz (deflated 94%)
#   adding: labels/PA000091.nii.gz (deflated 95%)
#   adding: labels/PA000121.nii.gz (deflated 95%)
#   adding: labels/PA000247.nii.gz (deflated 94%)
#   adding: labels/PA000016.nii.gz (deflated 95%)
#   adding: labels/PA000282.nii.gz (deflated 96%)
#   adding: labels/PA000207.nii.gz (deflated 94%)
